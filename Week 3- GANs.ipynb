# %%
import sys
import matplotlib.pyplot as plt
import numpy as np
import pickle
import glob
from __future__ import print_function, division
from music21 import converter, instrument, note, chord, stream
from keras.layers import Input, Dense, Reshape, Dropout, CuDNNLSTM, Bidirectional
from keras.layers import BatchNormalization, Activation, ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
from keras.utils import np_utils

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-3035d17b-0134-4189-a8a3-0acac0108f98" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3035d17b-0134-4189-a8a3-0acac0108f98">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Pokemon MIDIs.zip to Pokemon MIDIs.zip
# User uploaded file "Pokemon MIDIs.zip" with length 559309 bytes

# %%
# !unzip "Pokemon MIDIs.zip"
# Out:
# Archive:  Pokemon MIDIs.zip
#    creating: Pokemon MIDIs/
#   inflating: Pokemon MIDIs/Pokemon - Farewell, Pikachu!.mid
#   inflating: Pokemon MIDIs/Pokemon - Lavender town.mid
#   inflating: Pokemon MIDIs/Pokemon - Littleroot Town.mid
#   inflating: Pokemon MIDIs/Pokemon - Lugias Song.mid
#   inflating: Pokemon MIDIs/Pokemon - Oracion.mid
#   inflating: Pokemon MIDIs/Pokemon - Pallet Town.mid
#   inflating: Pokemon MIDIs/Pokemon - Pkmn Elite 4.mid
#   inflating: Pokemon MIDIs/Pokemon - pokecentre theme.mid
#   inflating: Pokemon MIDIs/Pokemon - Pokemon Center Theme.mid
#   inflating: Pokemon MIDIs/Pokemon - Pokemon Center.mid
#   inflating: Pokemon MIDIs/Pokemon - Pokemon Johto - Opening.mid
#   inflating: Pokemon MIDIs/Pokemon - The Ghost at Maiden's Peak.mid
#   inflating: Pokemon MIDIs/Pokemon Black & White - Village Bridge.mid
#   inflating: Pokemon MIDIs/Pokemon Black 2White 2 - Cave of Being.mid
#   inflating: Pokemon MIDIs/Pokemon Black 2White 2 - Join Avenue  Greeting.mid
#   inflating: Pokemon MIDIs/Pokemon Black 2White 2 - Ns Room.mid
#   inflating: Pokemon MIDIs/Pokemon Black 2White 2 - Ns Theme.mid
#   inflating: Pokemon MIDIs/Pokemon Black 2White 2 - THE END.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Accumula Town.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - An Unwavering Heart.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Battle CherenBianca.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Battle Elite Four.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Battle Legendary Pokemon.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Battle Team Plasma.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Battle Wild Pokemon.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Bicycle.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Castelia City.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Champion Alder.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Crisis in Battle.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Dragonspiral Tower.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Driftveil City.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Ending Onward to Our Own Futures.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Icirrus City.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Lacunosa Town.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Mistralton City.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Musical Hall.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - N the Pokemon Child.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Nacrene City.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Ns Castle.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Ns Farewell.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Nuvema Town.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Opelucid City White.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Pokemon League.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Relic Song.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Route 10.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Route 3.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Route 4.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Route 6.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Skyarrow Bridge.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Striaton City.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Surfing.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Undella Town FallWinterSpring.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Undella Town Summer.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - Village Bridge.mid
#   inflating: Pokemon MIDIs/Pokemon BlackWhite - White Forest.mid
#   inflating: Pokemon MIDIs/Pokemon Channel - Pokepad.mid
#   inflating: Pokemon MIDIs/Pokemon Colosseum - Miror B Battle.mid
#   inflating: Pokemon MIDIs/Pokemon Colosseum - Outskirt Stand.mid
#   inflating: Pokemon MIDIs/Pokemon Colosseum - Pyrite Town.mid
#   inflating: Pokemon MIDIs/Pokemon Colosseum - Relic Forest in Danger.mid
#   inflating: Pokemon MIDIs/Pokemon Colosseum - Relic Forest.mid
#   inflating: Pokemon MIDIs/Pokemon Colosseum - Semifinal Battle.mid
#   inflating: Pokemon MIDIs/Pokemon Colosseum - The Under.mid
#   inflating: Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Approaching Champion Cynthia.mid
#   inflating: Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Azelf Mesprit and Uxie Battle.mid
#   inflating: Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Battle Champion.mid
#   inflating: Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Battle Rival.mid
#   inflating: Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Battle Team Galactic Admin.mid
#   inflating: Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Battle Trainer.mid
#   inflating: Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Battle Wild Pokemon.mid
#   inflating: Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Canalave City.mid
#   inflating: Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Cyrus  Team Galactic Boss Battle.mid
#   inflating: Pokemon MIDIs/Pokemon DiamondPearlPlatinum
pokemon MIDIs/Pokemon Omega RubyAlpha Sapphire - Strains of a New Beginning Theme of rs.mid
#   inflating: Pokemon MIDIs/Pokemon Omega RubyAlpha Sapphire - The Lament of Falling Stars.mid
#   inflating: Pokemon MIDIs/Pokemon Omega RubyAlpha Sapphire - Trainers Eyes Meet Poke Fan.mid
#   inflating: Pokemon MIDIs/Pokemon Pinball - Catch Em and Evolution Mode in Red Field.mid
#   inflating: Pokemon MIDIs/Pokemon Pinball - Field Select.mid
#   inflating: Pokemon MIDIs/Pokemon Pinball - Pokedex.mid
#   inflating: Pokemon MIDIs/Pokemon Pinball - Red Field Theme.mid
#   inflating: Pokemon MIDIs/Pokemon Ranger - Ranger Base.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Celadon City.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Cerulean City.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Champion Battle.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Cinnabar Island.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Cycling.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Elite Four.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Ending Theme.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Evolution.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Game Corner Theme.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Gym Leader Battle.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Gym.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Hall of Fame.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Indigo Plateau.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Intro 1.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Intro 2.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Jigglypuffs Song.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Lavender Town.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Mt Moon.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Oaks Lab.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Opening Yellow.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Pallet Town.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Pokemon Center.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Pokemon Tower.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Printer Error.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Route 1.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Route 12.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Route 24.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Route 3.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Show Me Around.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Silph Co.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - SS Anne.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Surf Theme.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Team Rocket Hideout.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Title Theme.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Trainer Battle.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Vermillion City.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Viridian City.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Viridian Forest.mid
#   inflating: Pokemon MIDIs/Pokemon RedBlueYellow - Wild Pokemon Battle.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Abandoned Ship.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Battle Tower.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Champion Battle.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Desert.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Dewford Town.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Elite 4 Battle.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Ending Theme.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Evergrande City.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Fallarbor Town.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Fortree City.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Heavy Rain.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Lilycove City.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Lilycove Museum.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Littleroot Town.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Mt Pyre Peak.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Mt Pyre.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Oceanic Museum.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Oldale Town.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Petalburg City.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Pokemart.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Pokemon Contest.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Recovery.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Rival Battle.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Route 101.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Route 104.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Route 110.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Route 111 Desert.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Route 120.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Slateport City.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Sootopolis City.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Surfing.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Trainers School.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Trick House.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Verdanturf Town.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Wild Pokemon Battle.mid
#   inflating: Pokemon MIDIs/Pokemon RubySapphireEmerald - Wild Pokemon Caught or Fainted.mid
#   inflating: Pokemon MIDIs/Pokemon Snap - A Mysterious Sighting.mid
#   inflating: Pokemon MIDIs/Pokemon Snap - Snapshot Lullaby.mid
#   inflating: Pokemon MIDIs/Pokemon Trading Card Game - Title Screen.mid
#   inflating: Pokemon MIDIs/Pokemon X and Y - Calem and Serena.mid
#   inflating: Pokemon MIDIs/Pokemon XD Gale of Darkness - Mt Battle Lobby.mid
#   inflating: Pokemon MIDIs/Pokemon XD Gale of Darkness - The Hexagon Bros.mid
#   inflating: Pokemon MIDIs/Pokemon XY - Battle Wild Pokemon.mid
#   inflating: Pokemon MIDIs/Pokemon XY - Bicycle.mid
#   inflating: Pokemon MIDIs/Pokemon XY - Emmas Theme.mid
#   inflating: Pokemon MIDIs/Pokemon XY - FIN.mid
#   inflating: Pokemon MIDIs/Pokemon XY - Route 4567.mid
#   inflating: Pokemon MIDIs/Pokemon XY - The Sycamore Pokemon Lab.mid
#   inflating: Pokemon MIDIs/Pokemon XY - Together with Shauna.mid
#   inflating: Pokemon MIDIs/Pokemon Yellow - Lavender Town (Fixed).mid

# %%
def get_notes():
    """ Get all the notes and chords from the midi files """
    notes = []

    for file in glob.glob("Pokemon MIDIs/*.mid"):
        midi = converter.parse(file)

        print("Parsing %s" % file)

        notes_to_parse = None

        try: # file has instrument parts
            s2 = instrument.partitionByInstrument(midi)
            notes_to_parse = s2.parts[0].recurse() 
        except: # file has notes in a flat structure
            notes_to_parse = midi.flat.notes
            
        for element in notes_to_parse:
            if isinstance(element, note.Note):
                notes.append(str(element.pitch))
            elif isinstance(element, chord.Chord):
                notes.append('.'.join(str(n) for n in element.normalOrder))

    return notes

def prepare_sequences(notes, n_vocab):
    """ Prepare the sequences used by the Neural Network """
    sequence_length = 100

    # Get all pitch names
    pitchnames = sorted(set(item for item in notes))

    # Create a dictionary to map pitches to integers
    note_to_int = dict((note, number) for number, note in enumerate(pitchnames))

    network_input = []
    network_output = []

    # create input sequences and the corresponding outputs
    for i in range(0, len(notes) - sequence_length, 1):
        sequence_in = notes[i:i + sequence_length]
        sequence_out = notes[i + sequence_length]
        network_input.append([note_to_int[char] for char in sequence_in])
        network_output.append(note_to_int[sequence_out])

    n_patterns = len(network_input)

    # Reshape the input into a format compatible with LSTM layers
    network_input = np.reshape(network_input, (n_patterns, sequence_length, 1))
    
    # Normalize input between -1 and 1
    network_input = (network_input - float(n_vocab)/2) / (float(n_vocab)/2)
    network_output = np_utils.to_categorical(network_output)

    return (network_input, network_output)

def generate_notes(model, network_input, n_vocab):
    """ Generate notes from the neural network based on a sequence of notes """
    # pick a random sequence from the input as a starting point for the prediction
    start = numpy.random.randint(0, len(network_input)-1)
    
    # Get pitch names and store in a dictionary
    pitchnames = sorted(set(item for item in notes))
    int_to_note = dict((number, note) for number, note in enumerate(pitchnames))

    pattern = network_input[start]
    prediction_output = []

    # generate 500 notes
    for note_index in range(500):
        prediction_input = numpy.reshape(pattern, (1, len(pattern), 1))
        prediction_input = prediction_input / float(n_vocab)

        prediction = model.predict(prediction_input, verbose=0)

        index = numpy.argmax(prediction)
        result = int_to_note[index]
        prediction_output.append(result)
        
        pattern = numpy.append(pattern,index)
        #pattern.append(index)
        pattern = pattern[1:len(pattern)]

    return prediction_output
  
def create_midi(prediction_output, filename):
    """ convert the output from the prediction to notes and create a midi file
        from the notes """
    offset = 0
    output_notes = []

    # create note and chord objects based on the values generated by the model
    for item in prediction_output:
        pattern = item[0]
        # pattern is a chord
        if ('.' in pattern) or pattern.isdigit():
            notes_in_chord = pattern.split('.')
            notes = []
            for current_note in notes_in_chord:
                new_note = note.Note(int(current_note))
                new_note.storedInstrument = instrument.Piano()
                notes.append(new_note)
            new_chord = chord.Chord(notes)
            new_chord.offset = offset
            output_notes.append(new_chord)
        # pattern is a note
        else:
            new_note = note.Note(pattern)
            new_note.offset = offset
            new_note.storedInstrument = instrument.Piano()
            output_notes.append(new_note)

        # increase offset each iteration so that notes do not stack
        offset += 0.5

    midi_stream = stream.Stream(output_notes)
    midi_stream.write('midi', fp='{}.mid'.format(filename))

class GAN():
    def __init__(self, rows):
        self.seq_length = rows
        self.seq_shape = (self.seq_length, 1)
        self.latent_dim = 1000
        self.disc_loss = []
        self.gen_loss =[]
        
        optimizer = Adam(0.0002, 0.5)

        # Build and compile the discriminator
        self.discriminator = self.build_discriminator()
        self.discriminator.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

        # Build the generator
        self.generator = self.build_generator()

        # The generator takes noise as input and generates note sequences
        z = Input(shape=(self.latent_dim,))
        generated_seq = self.generator(z)

        # For the combined model we will only train the generator
        self.discriminator.trainable = False

        # The discriminator takes generated images as input and determines validity
        validity = self.discriminator(generated_seq)

        # The combined model  (stacked generator and discriminator)
        # Trains the generator to fool the discriminator
        self.combined = Model(z, validity)
        self.combined.compile(loss='binary_crossentropy', optimizer=optimizer)

    def build_discriminator(self):

        model = Sequential()
        model.add(CuDNNLSTM(512, input_shape=self.seq_shape, return_sequences=True))
        model.add(Bidirectional(CuDNNLSTM(512)))
        model.add(Dense(512))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dense(256))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dense(1, activation='sigmoid'))
        model.summary()

        seq = Input(shape=self.seq_shape)
        validity = model(seq)

        return Model(seq, validity)
      
    def build_generator(self):

        model = Sequential()
        model.add(Dense(256, input_dim=self.latent_dim))
        model.add(LeakyReLU(alpha=0.2))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(512))
        model.add(LeakyReLU(alpha=0.2))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(1024))
        model.add(LeakyReLU(alpha=0.2))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(np.prod(self.seq_shape), activation='tanh'))
        model.add(Reshape(self.seq_shape))
        model.summary()
        
        noise = Input(shape=(self.latent_dim,))
        seq = model(noise)

        return Model(noise, seq)

    def train(self, epochs, batch_size=128, sample_interval=50):

        # Load and convert the data
        notes = get_notes()
        n_vocab = len(set(notes))
        X_train, y_train = prepare_sequences(notes, n_vocab)

        # Adversarial ground truths
        real = np.ones((batch_size, 1))
        fake = np.zeros((batch_size, 1))
        
        # Training the model
        for epoch in range(epochs):

            # Training the discriminator
            # Select a random batch of note sequences
            idx = np.random.randint(0, X_train.shape[0], batch_size)
            real_seqs = X_train[idx]

            #noise = np.random.choice(range(484), (batch_size, self.latent_dim))
            #noise = (noise-242)/242
            noise = np.random.normal(0, 1, (batch_size, self.latent_dim))

            # Generate a batch of new note sequences
            gen_seqs = self.generator.predict(noise)

            # Train the discriminator
            d_loss_real = self.discriminator.train_on_batch(real_seqs, real)
            d_loss_fake = self.discriminator.train_on_batch(gen_seqs, fake)
            d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)


            #  Training the Generator
            noise = np.random.normal(0, 1, (batch_size, self.latent_dim))

            # Train the generator (to have the discriminator label samples as real)
            g_loss = self.combined.train_on_batch(noise, real)

            # Print the progress and save into loss lists
            if epoch % sample_interval == 0:
              print ("%d [D loss: %f, acc.: %.2f%%] [G loss: %f]" % (epoch, d_loss[0], 100*d_loss[1], g_loss))
              self.disc_loss.append(d_loss[0])
              self.gen_loss.append(g_loss)
        
        self.generate(notes)
        self.plot_loss()
        
    def generate(self, input_notes):
        # Get pitch names and store in a dictionary
        notes = input_notes
        pitchnames = sorted(set(item for item in notes))
        int_to_note = dict((number, note) for number, note in enumerate(pitchnames))
        
        # Use random noise to generate sequences
        noise = np.random.normal(0, 1, (1, self.latent_dim))
        predictions = self.generator.predict(noise)
        
        pred_notes = [x*242+242 for x in predictions[0]]
        pred_notes = [int_to_note[int(x)] for x in pred_notes]
        
        create_midi(pred_notes, 'gan_final')
        
    def plot_loss(self):
        plt.plot(self.disc_loss, c='red')
        plt.plot(self.gen_loss, c='blue')
        plt.title("GAN Loss per Epoch")
        plt.legend(['Discriminator', 'Generator'])
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.savefig('GAN_Loss_per_Epoch_final.png', transparent=True)
        plt.close()

# %%
if __name__ == '__main__':
  gan = GAN(rows=100)    
  gan.train(epochs=1000, batch_size=32, sample_interval=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  cu_dnnlstm (CuDNNLSTM)      (None, 100, 512)          1054720
#
#  bidirectional (Bidirectiona  (None, 1024)             4202496
#  l)
#
#  dense (Dense)               (None, 512)               524800
#
#  leaky_re_lu (LeakyReLU)     (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 256)               0
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 5,913,601
# Trainable params: 5,913,601
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 256)               256256
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 256)               0
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  dense_4 (Dense)             (None, 512)               131584
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 512)               0
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_5 (Dense)             (None, 1024)              525312
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 1024)              0
#
#  batch_normalization_2 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dense_6 (Dense)             (None, 100)               102500
#
#  reshape (Reshape)           (None, 100, 1)            0
#
# =================================================================
# Total params: 1,022,820
# Trainable params: 1,019,236
# Non-trainable params: 3,584
# _________________________________________________________________
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Pokemon March.mid
# Parsing Pokemon MIDIs/Pokemon BlackWhite - Battle Legendary Pokemon.mid
# Parsing Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Battle Team Galactic Admin.mid
# Parsing Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Route 228 Night.mid
# Parsing Pokemon MIDIs/Pokemon XY - Battle Wild Pokemon.mid
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Kanto Gym Leader Battle.mid
# Parsing Pokemon MIDIs/Pokemon Colosseum - Outskirt Stand.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Heartwarming.mid
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Route 38.mid
# Parsing Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Battle Trainer.mid
# Parsing Pokemon MIDIs/Pokemon BlackWhite - Relic Song.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - SS Anne.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Viridian City.mid
# Parsing Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Mystery Gift.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Route 3.mid
# Parsing Pokemon MIDIs/Pokemon - The Ghost at Maiden's Peak.mid
# Parsing Pokemon MIDIs/Pokemon XY - Together with Shauna.mid
# Parsing Pokemon MIDIs/Pokemon BlackWhite - Crisis in Battle.mid
# Parsing Pokemon MIDIs/Pokemon BlackWhite - Battle Team Plasma.mid
# Parsing Pokemon MIDIs/Pokemon BlackWhite - Dragonspiral Tower.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Cycling.mid
# Parsing Pokemon MIDIs/Pokemon Trading Card Game - Title Screen.mid
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Sprout Tower.mid
# Parsing Pokemon MIDIs/Pokemon BlackWhite - Musical Hall.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Palkias Onslaught.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Celadon City.mid
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Violet CityOlivine City.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Trainer Battle.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Apple Woods.mid
# Parsing Pokemon MIDIs/Pokemon XD Gale of Darkness - Mt Battle Lobby.mid
# Parsing Pokemon MIDIs/Pokemon - Pokemon Johto - Opening.mid
# Parsing Pokemon MIDIs/Pokemon RubySapphireEmerald - Pokemart.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon - Red Rescue Team - Pokemon Square.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon BlueRed Rescue Team - Questionnaire.mid
# Parsing Pokemon MIDIs/Pokemon Colosseum - Pyrite Town.mid
# Parsing Pokemon MIDIs/Pokemon RubySapphireEmerald - Littleroot Town.mid
# Parsing Pokemon MIDIs/Pokemon BlackWhite - An Unwavering Heart.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Lower Brine Cave.mid
# Parsing Pokemon MIDIs/Pokemon RubySapphireEmerald - Abandoned Ship.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Jigglypuffs Song.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Hidden Land.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Viridian Forest.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Route 24.mid
# Parsing Pokemon MIDIs/Pokemon BlackWhite - Undella Town FallWinterSpring.mid
# Parsing Pokemon MIDIs/Pokemon Pinball - Field Select.mid
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Staff Credits.mid
# Parsing Pokemon MIDIs/Pokemon RubySapphireEmerald - Sootopolis City.mid
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Ecruteak CityCianwood City.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - In the Hands of Fate.mid
# Parsing Pokemon MIDIs/Pokemon - pokecentre theme.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon Explorers of TimeDarknessSky -
mid
# Parsing Pokemon MIDIs/Pokemon RubySapphireEmerald - Fortree City.mid
# Parsing Pokemon MIDIs/Pokemon BlackWhite - Surfing.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Aegis Cave.mid
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Victory Road.mid
# Parsing Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Jubilife City Day.mid
# Parsing Pokemon MIDIs/Pokemon Colosseum - Semifinal Battle.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Defend Globe.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon BlueRed Rescue Team - Escape Through the Snow  Snow Refugees.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Dusk Forest.mid
# Parsing Pokemon MIDIs/Pokemon Snap - Snapshot Lullaby.mid
# Parsing Pokemon MIDIs/Pokemon RubySapphireEmerald - Surfing.mid
# Parsing Pokemon MIDIs/Pokemon HeartGoldSoulSilver - Pokemon Center.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Show Me Around.mid
# Parsing Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Battle Rival.mid
# Parsing Pokemon MIDIs/Pokemon Omega RubyAlpha Sapphire - Leaders Theme Team MagmaTeam Aqua.mid
# Parsing Pokemon MIDIs/Pokemon BlackWhite - Nuvema Town.mid
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Dance Theatre.mid
# Parsing Pokemon MIDIs/Pokemon RubySapphireEmerald - Oceanic Museum.mid
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Pokemon Lullaby.mid
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Dragons Den.mid
# Parsing Pokemon MIDIs/Pokemon Snap - A Mysterious Sighting.mid
# Parsing Pokemon MIDIs/Pokemon HeartGoldSoulSilver - Title.mid
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Professor Elms Lab.mid
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Gym.mid
# Parsing Pokemon MIDIs/Pokemon Colosseum - Relic Forest in Danger.mid
# Parsing Pokemon MIDIs/Pokemon Channel - Pokepad.mid
# Parsing Pokemon MIDIs/Pokemon Black 2White 2 - Ns Room.mid
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Route 32.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Team Rocket Hideout.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Game Corner Theme.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - The Gatekeepers.mid
# Parsing Pokemon MIDIs/Pokemon BlackWhite - Battle CherenBianca.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Opening Yellow.mid
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Union Cave.mid
# Parsing Pokemon MIDIs/Pokemon RubySapphireEmerald - Champion Battle.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Hidden Highland.mid
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Tin Tower.mid
# Parsing Pokemon MIDIs/Pokemon RubySapphireEmerald - Mt Pyre Peak.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Cerulean City.mid
# Parsing Pokemon MIDIs/Pokemon - Farewell, Pikachu!.mid
# Parsing Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Route 205 Night.mid
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Azalea TownBlackthorn City.mid
# Parsing Pokemon MIDIs/Pokemon DiamondPearlPlatinum - WiFi Lobby.mid
# Parsing Pokemon MIDIs/Pokemon BlackWhite - Pokemon League.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Route 1.mid
# Parsing Pokemon MIDIs/Pokemon BlackWhite - Ns Castle.mid
# Parsing Pokemon MIDIs/Pokemon RubySapphireEmerald - Battle Tower.mid
# Parsing Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Route 209.mid
# Parsing Pokemon MIDIs/Pokemon XY - Bicycle.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Oh No.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Drenched Bluff.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Printer Error.mid
# Parsing Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Hearthome City.mid
# Parsing Pokemon MIDIs/Pokemon HeartGoldSoulSilver - Cinnabar Island.mid
# Parsing Pokemon MIDIs/Pokemon Pinball - Red Field Theme.mid
# Parsing Pokemon MIDIs/Pokemon BlackWhite - Lacunosa Town.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Indigo Plateau.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Champion Battle.mid
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Menu.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon BlueRed Rescue Team - Sinister Woods.mid
# Parsing Pokemon MIDIs/Pokemon RubySapphireEmerald - Oldale Town.mid
# Parsing Pokemon MIDIs/Pokemon BlackWhite - Castelia City.mid
# Parsing Pokemon MIDIs/Pokemon HeartGoldSoulSilver - Viridian Forest.mid
# Parsing Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Torn WorldDistortion World.mid
# Parsing Pokemon MIDIs/Pokemon - Pkmn Elite 4.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Surf Theme.mid
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Johto Wild Pokemon Battle.mid
# Parsing Pokemon MIDIs/Pokemon XD Gale of Darkness - The Hexagon Bros.mid
# Parsing Pokemon MIDIs/Pokemon HeartGoldSoulSilver - Lyras Theme.mid
# Parsing Pokemon MIDIs/Pokemon - Lugias Song.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon BlueRed Rescue Team - Title Screen.mid
# Parsing Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Poketch Addition.mid
# Parsing Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Cyrus  Team Galactic Boss Battle.mid
# Parsing Pokemon MIDIs/Pokemon HeartGoldSoulSilver - New Bark Town.mid
# Parsing Pokemon MIDIs/Pokemon BlackWhite - Route 4.mid
# Parsing Pokemon MIDIs/Pokemon HeartGoldSoulSilver - PokeWalker Synchronisation.mid
# Parsing Pokemon MIDIs/Pokemon XY - Route 4567.mid
# Parsing Pokemon MIDIs/Pokemon BlackWhite - Mistralton City.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Pallet Town.mid
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Rival Battle.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Guildmaster Wigglytuff.mid
# Parsing Pokemon MIDIs/Pokemon - Lavender town.mid
# Parsing Pokemon MIDIs/Pokemon Black & White - Village Bridge.mid
# Parsing Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Research Lab.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon BlueRed Rescue Team - Parting.mid
# Parsing Pokemon MIDIs/Pokemon GoldSilverCrystal - Burned Tower.mid
# Parsing Pokemon MIDIs/Pokemon Colosseum - Miror B Battle.mid
# Parsing Pokemon MIDIs/Pokemon Black 2White 2 - Cave of Being.mid
# Parsing Pokemon MIDIs/Pokemon XY - FIN.mid
# Parsing Pokemon MIDIs/Pokemon RubySapphireEmerald - Pokemon Contest.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - At the End of the Day.mid
# Parsing Pokemon MIDIs/Pokemon Omega RubyAlpha Sapphire - Strains of a New Beginning Theme of rs.mid
# Parsing Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Floaroma Town.mid
# Parsing Pokemon MIDIs/Pokemon BlackWhite - Route 6.mid
# Parsing Pokemon MIDIs/Pokemon Gold, Silver, Crystal - S.S. Aqua .mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Cinnabar Island.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon Gates to Infinity - Desperation Light Arrangement.mid
# Parsing Pokemon MIDIs/Pokemon RubySapphireEmerald - Desert.mid
# Parsing Pokemon MIDIs/Pokemon RedBlueYellow - Intro 1.mid
# Parsing Pokemon MIDIs/Pokemon DiamondPearlPlatinum - Azelf Mesprit and Uxie Battle.mid
# Parsing Pokemon MIDIs/Pokemon HeartGoldSoulSilver - Instructions.mid
# Parsing Pokemon MIDIs/Pokemon BlackWhite - White Forest.mid
# Parsing Pokemon MIDIs/Pokemon RubySapphireEmerald - Evergrande City.mid
# Parsing Pokemon MIDIs/Pokemon RubySapphireEmerald - Route 104.mid
# Parsing Pokemon MIDIs/Pokemon RubySapphireEmerald - Wild Pokemon Battle.mid
# Parsing Pokemon MIDIs/Pokemon Mystery Dungeon Explorers of TimeDarknessSky -